# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
store_df = pd.read_csv("../input/rossmann-store-sales/store.csv")
train_df = pd.read_csv("../input/rossmann-store-sales/train.csv")
test_df =  pd.read_csv("../input/rossmann-store-sales/test.csv")
submission_df = pd.read_csv("../input/rossmann-store-sales/sample_submission.csv")

# %%
print("train_df shape", train_df.shape)
print("test_df shape",test_df.shape)
print("store_df shape", store_df.shape)
print("submission_df shape", submission_df.shape)

# %%
train_df.head()

# %%
test_df.head()

# %%
store_df.head()

# %%
#Merging the Store Dataset with the train & test set
merged_df = train_df.merge(store_df,how="left",on="Store")
merged_test_df=test_df.merge(store_df,how="left",on="Store")

# %% [markdown]
# **Looking at the Dataset**

# %%
merged_df

# %%
merged_df.describe()

# %% [markdown]
# ## Customers feature

# %%
merged_df["Customers"].value_counts()

# %%
px.histogram(merged_df, x="Customers",title="Total Customers",width=600,height=400)

# %% [markdown]
# ## Sales Feature

# %%
merged_df["Sales"].value_counts()

# %%
px.histogram(merged_df,x="Sales",title="Total Sales",width=800,height=600)

# %% [markdown]
# ## Day of Week

# %%
merged_df["DayOfWeek"].value_counts().sort_values()

# %% [markdown]
# ## Years

# %%
merged_df["Year"]= pd.to_datetime(merged_df["Date"]).dt.year

plt.title("Years in the Dataset")
matplotlib.rcParams["figure.figsize"]= 18,6
sns.set_style("darkgrid")

sns.countplot(data=merged_df,x="Year");

# %%
merged_df["Year"].value_counts()

# %% [markdown]
# ## Month

# %%
merged_df["Month"] = pd.to_datetime(merged_df["Date"]).dt.month

sns.countplot(data= merged_df, x="Month");

# %%
9merged_df["Month"].value_counts()

# %%
merged_df["Open"].value_counts()

# %%
sns.countplot(data=merged_df,x= "Open");

# %% [markdown]
# ## Watching the Correlation with the Target

# %%
sns.heatmap(merged_df.corr(),annot=True,cmap="Blues");

# %%
plt.title('Relationship between Customers and Sales',fontsize=20)
sns.scatterplot(data=merged_df,x="Customers",y="Sales");

# %%
sns.boxplot(data=merged_df,x="DayOfWeek",y="Sales",linewidth=2.5);

# %%
plt.title("Relationshipsns.boxplot(data=merged_df,x="Promo",y="Sales",linewidth=2.5);
